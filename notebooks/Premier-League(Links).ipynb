# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/fbref_Premier-League_2023-2024_fixtures.csv")
df
# Out:
#        Wk  Day        Date   Time             Home   xG Score  xG.1  \
# 0     1.0  Fri  2023-08-11  20:00          Burnley  0.3   0–3   1.9
# 1     1.0  Sat  2023-08-12  12:30          Arsenal  0.8   2–1   1.2
# 2     1.0  Sat  2023-08-12  15:00          Everton  2.7   0–1   1.5
# 3     1.0  Sat  2023-08-12  15:00         Brighton  4.0   4–1   1.5
# 4     1.0  Sat  2023-08-12  15:00    Sheffield Utd  0.5   0–1   1.9
# ..    ...  ...         ...    ...              ...  ...   ...   ...
# 375  38.0  Sun  2024-05-19  16:00         Brighton  1.7   0–2   1.3
# 376  38.0  Sun  2024-05-19  16:00        Brentford  1.1   2–4   3.4
# 377  38.0  Sun  2024-05-19  16:00  Manchester City  1.9   3–1   0.4
# 378  38.0  Sun  2024-05-19  16:00          Arsenal  2.9   2–1   0.6
# 379  38.0  Sun  2024-05-19  16:00    Sheffield Utd  1.0   0–3   3.1
#
#                 Away  Attendance                                   Venue  \
# 0    Manchester City     21572.0                               Turf Moor
# ...

# %%
df['Match URL']
# Out:
# 0      https://fbref.com/en/matches/3a6836b4/Burnley-...
# 1      https://fbref.com/en/matches/26a7f90c/Arsenal-...
# 2      https://fbref.com/en/matches/15addfc7/Everton-...
# 3      https://fbref.com/en/matches/56a137f7/Brighton...
# 4      https://fbref.com/en/matches/55fd92c7/Sheffiel...
#                              ...
# 375    https://fbref.com/en/matches/47ecdc19/Brighton...
# 376    https://fbref.com/en/matches/546e1a3d/Brentfor...
# 377    https://fbref.com/en/matches/29335211/Manchest...
# 378    https://fbref.com/en/matches/3e33bd98/Arsenal-...
# 379    https://fbref.com/en/matches/273a89b4/Sheffiel...
# Name: Match URL, Length: 380, dtype: object

# %%
df['Match URL'].isnull().sum()
# Out:
# np.int64(0)
